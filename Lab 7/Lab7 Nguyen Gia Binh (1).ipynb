# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.5/877.5 kB 13.8 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov10m.pt')
# Out:
# ...
# 100%|██████████| 32.1M/32.1M [00:00<00:00, 68.9MB/s]

# %%
model.predict(source='/kaggle/input/testing/a81b5e69-d102-4c34-bb3a-d79c9c5f3b77.jpg', save=True)
# Out:
# image 1/1 /kaggle/input/testing/a81b5e69-d102-4c34-bb3a-d79c9c5f3b77.jpg: 480x640 1 mouse, 3 cell phones, 685.3ms
# Speed: 3.2ms preprocess, 685.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

img1 = Image.open("/kaggle/working/runs/detect/predict/2af85537-9ddb-45d1-b650-304957882ecf.jpg")
img2 = Image.open("/kaggle/working/runs/detect/predict/a81b5e69-d102-4c34-bb3a-d79c9c5f3b77.jpg")

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img1)

plt.subplot(1, 2, 2)
plt.imshow(img2)

plt.show()
